# %%
import numpy as np
import os
import cv2 as cv
import matplotlib.pyplot as plt
from keras import datasets, Sequential
from keras.layers import Conv2D, Dense, MaxPooling2D, Flatten
from sklearn.metrics import confusion_matrix
from keras.utils import np_utils
from keras.datasets import cifar10
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import  image
from keras.preprocessing.image import load_img, img_to_array,array_to_img,ImageDataGenerator

# %%
Fruit = ['banana','dragon-fruit','guava','jackfruit','mango','mangosteen','melon','papaya','pineapple','water-melon']
dir_train = '/content/drive/MyDrive/fruit-recognition' 
distpath = []
X_train = []
y_train = []
X_test = []
y_test = []

# %%
def create_data(dir, x_train, y_train):
  for i in Fruit:
    path = os.path.join(dir,i)
    index_label = Fruit.index(i)
    for j in os.listdir(path):
      img_path = os.path.join(path, j)
      img = image.load_img(img_path, target_size=(150,150)) 
      img = img_to_array(img)
      img = img.reshape(150,150,3) 
      img = img.astype('float32')
      img = img/255
      X_train.append(img)
      y_train.append(index_label)
create_data(dir_train, X_train, y_train)

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)
y_train = np_utils.to_categorical(y_train, 10)
print(X_train.shape) 
print(y_train.shape)
# Out:
# (100, 150, 150, 3)
# (100, 10)

# %%
model = Sequential()
model.add(Conv2D(filters=32,kernel_size=(27,48),activation='relu',kernel_initializer='he_uniform',padding='same',input_shape=(150,150,3),strides=(9,16)))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(filters=64,kernel_size=(27,48), activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(filters=128,kernel_size=(27,48), activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(512, activation='relu',input_shape=(67500,), name='layer1')) 
model.add(Dense(1028, activation='relu', name='layer2'))
model.add(Dense(1028, activation='relu', name='layer3'))
model.add(Dense(10, activation='softmax', name='layer4'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 17, 10, 32)        124448
#
#  max_pooling2d (MaxPooling2D  (None, 8, 5, 32)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 8, 5, 64)          2654272
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 2, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 2, 128)         10616960
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 1, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  layer1 (Dense)              (None, 512)               131584
#
#  layer2 (Dense)              (None, 1028)              527364
#
#  layer3 (Dense)              (None, 1028)              1057812
#
#  layer4 (Dense)              (None, 10)                10290
#
# =================================================================
# Total params: 15,122,730
# Trainable params: 15,122,730
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])
history = model.fit(X_train,y_train,epochs = 100, verbose=1,batch_size=40)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 8s 2s/step - loss: 2.3523 - accuracy: 0.0400
# Epoch 2/100
# 3/3 [==============================] - 9s 3s/step - loss: 2.3060 - accuracy: 0.0700
# Epoch 3/100
# 3/3 [==============================] - 9s 2s/step - loss: 2.3032 - accuracy: 0.0700
# Epoch 4/100
# 3/3 [==============================] - 7s 2s/step - loss: 2.3009 - accuracy: 0.1000
# Epoch 5/100
# 3/3 [==============================] - 7s 2s/step - loss: 2.2923 - accuracy: 0.0900
# Epoch 6/100
# 3/3 [==============================] - 7s 2s/step - loss: 2.2932 - accuracy: 0.1000
# Epoch 7/100
# 3/3 [==============================] - 7s 2s/step - loss: 2.2831 - accuracy: 0.1100
# Epoch 8/100
# 3/3 [==============================] - 7s 2s/step - loss: 2.2879 - accuracy: 0.0800
# Epoch 9/100
# 3/3 [==============================] - 7s 2s/step - loss: 2.2509 - accuracy: 0.1700
# Epoch 10/100
# 3/3 [==============================] - 8s 2s/step - loss: 2.2221 - accuracy: 0.1800
# Epoch 11/100
# 3/3 [==============================] - 7s 2s/step - loss: 2.1812 - accuracy: 0.1900
# Epoch 12/100
# 3/3 [==============================] - 7s 2s/step - loss: 2.1553 - accuracy: 0.1800
# Epoch 13/100
# 3/3 [==============================] - 7s 2s/step - loss: 2.1283 - accuracy: 0.1800
# Epoch 14/100
# 3/3 [==============================] - 7s 2s/step - loss: 2.0488 - accuracy: 0.1600
# Epoch 15/100
# 3/3 [==============================] - 7s 2s/step - loss: 1.9926 - accuracy: 0.2100
# Epoch 16/100
# 3/3 [==============================] - 7s 2s/step - loss: 1.9454 - accuracy: 0.2500
# Epoch 17/100
# 3/3 [==============================] - 7s 2s/step - loss: 1.8857 - accuracy: 0.2000
# Epoch 18/100
# 3/3 [==============================] - 7s 2s/step - loss: 1.8270 - accuracy: 0.2700
# Epoch 19/100
# 3/3 [==============================] - 7s 2s/step - loss: 1.7546 - accuracy: 0.2600
# Epoch 20/100
# 3/3 [==============================] - 7s 2s/step - loss: 1.8276 - accuracy: 0.2800
# Epoch 21/100
# 3/3 [==============================] - 7s 2s/step - loss: 1.8568 - accuracy: 0.2700
# Epoch 22/100
# 3/3 [==============================] - 7s 2s/step - loss: 1.8336 - accuracy: 0.2800
# Epoch 23/100
# 3/3 [==============================] - 7s 2s/step - loss: 1.8435 - accuracy: 0.2500
# Epoch 24/100
# 3/3 [==============================] - 7s 2s/step - loss: 1.6851 - accuracy: 0.3000
# Epoch 25/100
# 3/3 [==============================] - 7s 2s/step - loss: 1.8752 - accuracy: 0.2100
# Epoch 26/100
# 3/3 [==============================] - 7s 2s/step - loss: 1.6966 - accuracy: 0.2600
# Epoch 27/100
# 3/3 [==============================] - 7s 2s/step - loss: 1.6619 - accuracy: 0.3300
# Epoch 28/100
# 3/3 [==============================] - 7s 2s/step - loss: 1.5781 - accuracy: 0.3300
# Epoch 29/100
# 3/3 [==============================] - 7s 2s/step - loss: 1.4880 - accuracy: 0.3200
# Epoch 30/100
# 3/3 [==============================] - 7s 2s/step - loss: 1.3860 - accuracy: 0.4100
# Epoch 31/100
# 3/3 [==============================] - 7s 2s/step - loss: 1.2924 - accuracy: 0.4200
# Epoch 32/100
# 3/3 [==============================] - 7s 2s/step - loss: 1.2798 - accuracy: 0.4400
# Epoch 33/100
# 3/3 [==============================] - 7s 2s/step - loss: 1.2342 - accuracy: 0.5700
# Epoch 34/100
# 3/3 [==============================] - 7s 2s/step - loss: 1.2439 - accuracy: 0.4800
# Epoch 35/100
# 3/3 [==============================] - 7s 2s/step - loss: 1.0437 - accuracy: 0.5600
# Epoch 36/100
# 3/3 [==============================] - 7s 2s/step - loss: 1.0928 - accuracy: 0.5200
# Epoch 37/100
# 3/3 [==============================] - 7s 2s/step - loss: 1.0466 - accuracy: 0.5700
# Epoch 38/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.8975 - accuracy: 0.6900
# Epoch 39/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.8643 - accuracy: 0.6000
# Epoch 40/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.8841 - accuracy: 0.6900
# Epoch 41/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.7049 - accuracy: 0.7600
# Epoch 42/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.7820 - accuracy: 0.7000
# Epoch 43/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.6455 - accuracy: 0.7400
# Epoch 44/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.5963 - accuracy: 0.7800
# Epoch 45/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.5618 - accuracy: 0.8000
# Epoch 46/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.5067 - accuracy: 0.8100
# Epoch 47/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.7156 - accuracy: 0.7800
# Epoch 48/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.6448 - accuracy: 0.7900
# Epoch 49/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.5089 - accuracy: 0.8600
# Epoch 50/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.4779 - accuracy: 0.8000
# Epoch 51/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.4751 - accuracy: 0.8500
# Epoch 52/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.3225 - accuracy: 0.8800
# Epoch 53/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.3571 - accuracy: 0.9100
# Epoch 54/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.3116 - accuracy: 0.8900
# Epoch 55/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.2815 - accuracy: 0.9100
# Epoch 56/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.2766 - accuracy: 0.8400
# Epoch 57/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.4846 - accuracy: 0.8100
# Epoch 58/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.3539 - accuracy: 0.8700
# Epoch 59/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.3947 - accuracy: 0.8400
# Epoch 60/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.3960 - accuracy: 0.8700
# Epoch 61/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.5125 - accuracy: 0.8000
# Epoch 62/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.5181 - accuracy: 0.8200
# Epoch 63/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.6248 - accuracy: 0.8200
# Epoch 64/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.4466 - accuracy: 0.8300
# Epoch 65/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.4366 - accuracy: 0.8800
# Epoch 66/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.3462 - accuracy: 0.8400
# Epoch 67/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.2013 - accuracy: 0.9400
# Epoch 68/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.1532 - accuracy: 0.9700
# Epoch 69/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.1520 - accuracy: 0.9600
# Epoch 70/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0669 - accuracy: 1.0000
# Epoch 71/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0678 - accuracy: 0.9900
# Epoch 72/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0764 - accuracy: 0.9800
# Epoch 73/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0343 - accuracy: 1.0000
# Epoch 74/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0243 - accuracy: 1.0000
# Epoch 75/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 76/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 77/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 78/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 79/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 80/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 81/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 82/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 83/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 84/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 85/100
# 3/3 [==============================] - 7s 2s/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 86/100
# 3/3 [==============================] - 7s 2s/step - loss: 8.4571e-04 - accuracy: 1.0000
# Epoch 87/100
# 3/3 [==============================] - 7s 2s/step - loss: 7.4238e-04 - accuracy: 1.0000
# Epoch 88/100
# 3/3 [==============================] - 7s 2s/step - loss: 6.9712e-04 - accuracy: 1.0000
# Epoch 89/100
# 3/3 [==============================] - 7s 2s/step - loss: 6.4363e-04 - accuracy: 1.0000
# Epoch 90/100
# 3/3 [==============================] - 7s 2s/step - loss: 5.5905e-04 - accuracy: 1.0000
# Epoch 91/100
# 3/3 [==============================] - 7s 2s/step - loss: 4.8976e-04 - accuracy: 1.0000
# Epoch 92/100
# 3/3 [==============================] - 7s 2s/step - loss: 4.2259e-04 - accuracy: 1.0000
# Epoch 93/100
# 3/3 [==============================] - 7s 2s/step - loss: 3.8435e-04 - accuracy: 1.0000
# Epoch 94/100
# 3/3 [==============================] - 7s 2s/step - loss: 3.5517e-04 - accuracy: 1.0000
# Epoch 95/100
# 3/3 [==============================] - 7s 2s/step - loss: 3.3145e-04 - accuracy: 1.0000
# Epoch 96/100
# 3/3 [==============================] - 7s 2s/step - loss: 3.1334e-04 - accuracy: 1.0000
# Epoch 97/100
# 3/3 [==============================] - 7s 2s/step - loss: 2.9752e-04 - accuracy: 1.0000
# Epoch 98/100
# 3/3 [==============================] - 7s 2s/step - loss: 2.8321e-04 - accuracy: 1.0000
# Epoch 99/100
# 3/3 [==============================] - 7s 2s/step - loss: 2.6996e-04 - accuracy: 1.0000
# Epoch 100/100
# 3/3 [==============================] - 7s 2s/step - loss: 2.5727e-04 - accuracy: 1.0000

# %%
model.save('Fruit.h5')

# %%
filename = '/content/drive/MyDrive/fruit-recognition/water-melonTest.jpg'  
food = image.load_img(filename, target_size=(150,150))
plt.imshow(food)
food = img_to_array(food)
food = food.reshape(1,150,150,3) 
food = food.astype('float32')
food = food/255
np.argmax(model.predict(food), axis=1)

if np.argmax(model.predict(food)) == 0:
   print("banana")
if np.argmax(model.predict(food)) == 1:
   print("dragon-fruit")
if np.argmax(model.predict(food)) == 2:
   print("guava")
if np.argmax(model.predict(food)) == 3:
   print("jackfruit")
if np.argmax(model.predict(food)) == 4:
   print("mango")
if np.argmax(model.predict(food)) == 5:
   print("mangosteen")
if np.argmax(model.predict(food)) == 6:
   print("melon")
if np.argmax(model.predict(food)) == 7:
   print("papaya")
if np.argmax(model.predict(food)) == 8:
   print("pineapple")
if np.argmax(model.predict(food)) == 9:
   print("water-melon")
# Out:
# water-melon

# %%
filename = '/content/drive/MyDrive/fruit-recognition/mangoTest.jpg'  
food = image.load_img(filename, target_size=(150,150))
plt.imshow(food)
food = img_to_array(food)
food = food.reshape(1,150,150,3) 
food = food.astype('float32')
food = food/255
np.argmax(model.predict(food), axis=1)

if np.argmax(model.predict(food)) == 0:
   print("banana")
if np.argmax(model.predict(food)) == 1:
   print("dragon-fruit")
if np.argmax(model.predict(food)) == 2:
   print("guava")
if np.argmax(model.predict(food)) == 3:
   print("jackfruit")
if np.argmax(model.predict(food)) == 4:
   print("mango")
if np.argmax(model.predict(food)) == 5:
   print("mangosteen")
if np.argmax(model.predict(food)) == 6:
   print("melon")
if np.argmax(model.predict(food)) == 7:
   print("papaya")
if np.argmax(model.predict(food)) == 8:
   print("pineapple")
if np.argmax(model.predict(food)) == 9:
   print("water-melon")
# Out:
# mango
