# %%
import numpy as np
import os
import cv2 as cv
import matplotlib.pyplot as plt
from keras import datasets, Sequential
from keras.layers import Conv2D, Dense, MaxPooling2D, Flatten
from sklearn.metrics import confusion_matrix
from keras.utils import np_utils
from keras.datasets import cifar10
from tensorflow.keras.optimizers import Adam
from keras.preprocessing import  image
from keras.preprocessing.image import load_img, img_to_array,array_to_img,ImageDataGenerator

# %%
Food = ['1k','2k','5k','10k','20k','50k','100k','200k','500k']
dir_train = '/content/drive/MyDrive/Money-recognition' 
distpath = []
X_train = []
y_train = []
X_test = []
y_test = []

# %%
def create_data(dir, x_train, y_train):
  for i in Food:
    path = os.path.join(dir,i)
    index_label = Food.index(i)
    for j in os.listdir(path):
      img_path = os.path.join(path, j)
      img = image.load_img(img_path, target_size=(150,150)) 
      img = img_to_array(img)
      img = img.reshape(150,150,3) 
      img = img.astype('float32')
      img = img/255
      X_train.append(img)
      y_train.append(index_label)
create_data(dir_train, X_train, y_train)

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)
y_train = np_utils.to_categorical(y_train, 10)
print(X_train.shape) 
print(y_train.shape)
# Out:
# (90, 150, 150, 3)
# (90, 10)

# %%
model = Sequential()
model.add(Conv2D(filters=32,kernel_size=(27,48),activation='relu',kernel_initializer='he_uniform',padding='same',input_shape=(150,150,3),strides=(9,16)))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(filters=64,kernel_size=(27,48), activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(filters=128,kernel_size=(27,48), activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(512, activation='relu',input_shape=(67500,), name='layer1')) 
model.add(Dense(1028, activation='relu', name='layer2'))
model.add(Dense(1028, activation='relu', name='layer3'))
model.add(Dense(10, activation='softmax', name='layer4'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 17, 10, 32)        124448
#
#  max_pooling2d (MaxPooling2D  (None, 8, 5, 32)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 8, 5, 64)          2654272
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 2, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 2, 128)         10616960
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 1, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  layer1 (Dense)              (None, 512)               131584
#
#  layer2 (Dense)              (None, 1028)              527364
#
#  layer3 (Dense)              (None, 1028)              1057812
#
#  layer4 (Dense)              (None, 10)                10290
#
# =================================================================
# Total params: 15,122,730
# Trainable params: 15,122,730
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])
history = model.fit(X_train,y_train,epochs = 100, verbose=1,batch_size=40)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 6s 1s/step - loss: 2.3075 - accuracy: 0.0556
# Epoch 2/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2638 - accuracy: 0.1111
# Epoch 3/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2558 - accuracy: 0.1111
# Epoch 4/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2496 - accuracy: 0.1111
# Epoch 5/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2477 - accuracy: 0.1111
# Epoch 6/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2396 - accuracy: 0.1111
# Epoch 7/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2341 - accuracy: 0.1111
# Epoch 8/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2200 - accuracy: 0.0889
# Epoch 9/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2256 - accuracy: 0.1111
# Epoch 10/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2107 - accuracy: 0.1111
# Epoch 11/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2221 - accuracy: 0.1000
# Epoch 12/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2169 - accuracy: 0.1222
# Epoch 13/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2131 - accuracy: 0.1111
# Epoch 14/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2135 - accuracy: 0.1111
# Epoch 15/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2155 - accuracy: 0.0889
# Epoch 16/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2102 - accuracy: 0.1111
# Epoch 17/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2117 - accuracy: 0.1111
# Epoch 18/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2138 - accuracy: 0.1111
# Epoch 19/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2108 - accuracy: 0.1222
# Epoch 20/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2072 - accuracy: 0.1444
# Epoch 21/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2082 - accuracy: 0.1111
# Epoch 22/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2090 - accuracy: 0.1111
# Epoch 23/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2091 - accuracy: 0.1111
# Epoch 24/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2065 - accuracy: 0.1111
# Epoch 25/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2029 - accuracy: 0.1111
# Epoch 26/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2023 - accuracy: 0.1000
# Epoch 27/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2022 - accuracy: 0.1222
# Epoch 28/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2053 - accuracy: 0.1111
# Epoch 29/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.1995 - accuracy: 0.1111
# Epoch 30/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2014 - accuracy: 0.1111
# Epoch 31/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2016 - accuracy: 0.1111
# Epoch 32/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2037 - accuracy: 0.1111
# Epoch 33/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.1950 - accuracy: 0.1667
# Epoch 34/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.1919 - accuracy: 0.1222
# Epoch 35/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.1849 - accuracy: 0.1222
# Epoch 36/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.1789 - accuracy: 0.1333
# Epoch 37/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.1746 - accuracy: 0.1222
# Epoch 38/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.1814 - accuracy: 0.1333
# Epoch 39/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.1673 - accuracy: 0.1556
# Epoch 40/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2234 - accuracy: 0.1333
# Epoch 41/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.1497 - accuracy: 0.1333
# Epoch 42/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.1684 - accuracy: 0.1444
# Epoch 43/100
# 3/3 [==============================] - 5s 1s/step - loss: 2.1724 - accuracy: 0.1222
# Epoch 44/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.1408 - accuracy: 0.1444
# Epoch 45/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.1731 - accuracy: 0.1222
# Epoch 46/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.1399 - accuracy: 0.2000
# Epoch 47/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.1622 - accuracy: 0.2111
# Epoch 48/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.1184 - accuracy: 0.1444
# Epoch 49/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.0638 - accuracy: 0.2000
# Epoch 50/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.1408 - accuracy: 0.2333
# Epoch 51/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.2701 - accuracy: 0.1667
# Epoch 52/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.1277 - accuracy: 0.2333
# Epoch 53/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.0503 - accuracy: 0.2222
# Epoch 54/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.9046 - accuracy: 0.2444
# Epoch 55/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.7956 - accuracy: 0.2222
# Epoch 56/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.8232 - accuracy: 0.1889
# Epoch 57/100
# 3/3 [==============================] - 4s 1s/step - loss: 2.0164 - accuracy: 0.1889
# Epoch 58/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.8931 - accuracy: 0.2333
# Epoch 59/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.7659 - accuracy: 0.2333
# Epoch 60/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.7857 - accuracy: 0.2111
# Epoch 61/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.7171 - accuracy: 0.2667
# Epoch 62/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.6986 - accuracy: 0.2667
# Epoch 63/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.6671 - accuracy: 0.2778
# Epoch 64/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.6602 - accuracy: 0.2556
# Epoch 65/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.7162 - accuracy: 0.2333
# Epoch 66/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.5690 - accuracy: 0.3000
# Epoch 67/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.5761 - accuracy: 0.3111
# Epoch 68/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.5760 - accuracy: 0.3556
# Epoch 69/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.5679 - accuracy: 0.3222
# Epoch 70/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.4816 - accuracy: 0.3444
# Epoch 71/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.4892 - accuracy: 0.3333
# Epoch 72/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.4669 - accuracy: 0.3889
# Epoch 73/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.3857 - accuracy: 0.4111
# Epoch 74/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.3394 - accuracy: 0.4000
# Epoch 75/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.2522 - accuracy: 0.5111
# Epoch 76/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.2400 - accuracy: 0.5111
# Epoch 77/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.0893 - accuracy: 0.6000
# Epoch 78/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.0642 - accuracy: 0.5667
# Epoch 79/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.0230 - accuracy: 0.5889
# Epoch 80/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.9634 - accuracy: 0.5556
# Epoch 81/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.9077 - accuracy: 0.6111
# Epoch 82/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.8330 - accuracy: 0.6444
# Epoch 83/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.8172 - accuracy: 0.6444
# Epoch 84/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.7258 - accuracy: 0.7000
# Epoch 85/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.8104 - accuracy: 0.6556
# Epoch 86/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.8900 - accuracy: 0.6333
# Epoch 87/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.9605 - accuracy: 0.5667
# Epoch 88/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.1332 - accuracy: 0.5444
# Epoch 89/100
# 3/3 [==============================] - 4s 1s/step - loss: 1.2102 - accuracy: 0.6000
# Epoch 90/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.8498 - accuracy: 0.7222
# Epoch 91/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.8227 - accuracy: 0.7222
# Epoch 92/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.7242 - accuracy: 0.7667
# Epoch 93/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.6914 - accuracy: 0.7667
# Epoch 94/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.6286 - accuracy: 0.8000
# Epoch 95/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.4799 - accuracy: 0.8667
# Epoch 96/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.6092 - accuracy: 0.7556
# Epoch 97/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.5909 - accuracy: 0.7333
# Epoch 98/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.4764 - accuracy: 0.8222
# Epoch 99/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.4403 - accuracy: 0.8111
# Epoch 100/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.7210 - accuracy: 0.7111

# %%
model.save('Money.h5')

# %%
filename = '/content/drive/MyDrive/Money-recognition/10kTest.jpg'    
food = image.load_img(filename, target_size=(150,150))
plt.imshow(food)
food = img_to_array(food)
food = food.reshape(1,150,150,3) 
food = food.astype('float32')
food = food/255
np.argmax(model.predict(food), axis=1)

if np.argmax(model.predict(food)) == 0:
   print("1k")
if np.argmax(model.predict(food)) == 1:
   print("2k")
if np.argmax(model.predict(food)) == 2:
   print("5k")
if np.argmax(model.predict(food)) == 3:
   print("10k")
if np.argmax(model.predict(food)) == 4:
   print("20k")
if np.argmax(model.predict(food)) == 5:
   print("50k")
if np.argmax(model.predict(food)) == 6:
   print("100k")
if np.argmax(model.predict(food)) == 7:
   print("200k")
if np.argmax(model.predict(food)) == 8:
   print("500k")
# Out:
# 10k
